# %%
from pathlib import Path
import sys


sys.path.append(str(Path("..").resolve()))

from analyze import visualize_model

visualize_model(model_path='../checkpoints/model_final.pth', output_folder='../grid_plots/', save_imgs=True)
# Out:
# Saving plots to: /Users/navneetp/Documents/TopoGridCells/grid_plots
# Model loaded and set to eval
# Simulating 30 minute time
# Computing ratemaps and plotting
# Saved 0/512
# Saved 50/512
# Saved 100/512
# Saved 150/512
# Saved 200/512
# Saved 250/512
# Saved 300/512
# Saved 350/512
# Saved 400/512
# Saved 450/512
# Saved 500/512
# Done plotting
