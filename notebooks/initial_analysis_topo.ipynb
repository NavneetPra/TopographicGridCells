# %%
import os
import sys


directory_path = os.path.abspath('../')

if directory_path not in sys.path:
    sys.path.append(directory_path)

from analyze import visualize_cells

visualize_cells('../trained_models/trained_topographic.pth', '../grid_plots', save_imgs=False)
# Out:
# Trajectory Generator initialized:
# Mean speed: 1.024 m/s
# Mean ego_v (displacement/step): 0.0205 m
# Expected velocity input magnitude: ~0.0205
# ...
# Collected 10/50 batches
# Collected 20/50 batches
# Collected 30/50 batches
# Collected 40/50 batches
# Collected 50/50 batches
# Position range: x=[-1.13, 1.13], y=[-1.13, 1.13]
# Making ratemaps for all cells
# Processed 500/4096 cells
# Processed 1000/4096 cells
# Processed 1500/4096 cells
# Processed 2000/4096 cells
# Processed 2500/4096 cells
# Processed 3000/4096 cells
# Processed 3500/4096 cells
# Processed 4000/4096 cells
# Grid scores range: [-0.371, 1.415]
# Mean: 0.383, Median: 0.335
# Visualization complete
# (array([ 0.6011859 ,  0.20727931,  0.34060489, ...,  0.06688818,
#         -0.07330395, -0.06865478], shape=(4096,)),
#  array([[[4.83479172e-04, 8.22741976e-04, 2.09478551e-04, ...,
#           5.53819835e-04, 2.26542990e-04, 3.54112510e-04],
#          [1.46432946e-03, 1.18577134e-03, 6.89333615e-04, ...,
# ...

# %%
import os
import sys


directory_path = os.path.abspath('../')

if directory_path not in sys.path:
    sys.path.append(directory_path)

from analyze import visualize_pred
visualize_pred('../trained_models/trained_topographic.pth')
# Out:
# Trajectory Generator initialized:
# Mean speed: 1.024 m/s
# Mean ego_v (displacement/step): 0.0205 m
# Expected velocity input magnitude: ~0.0205
# Mean position error: 92.29 cm
# Prediction visualization complete

# %%
import os
import sys


directory_path = os.path.abspath('../')

if directory_path not in sys.path:
    sys.path.append(directory_path)

from analyze import visualize_trajectory_decoding

visualize_trajectory_decoding('../trained_models/trained_topographic.pth', n_trajectories=25, seq_length=20)
# Out:
# Trajectory Generator initialized:
# Mean speed: 1.024 m/s
# Mean ego_v (displacement/step): 0.0205 m
# Expected velocity input magnitude: ~0.0205
# Mean position error: 4.85 cm

# %%
import os
import sys


directory_path = os.path.abspath('../')

if directory_path not in sys.path:
    sys.path.append(directory_path)

from analyze import visualize_grid_scores

scores, ratemaps = visualize_grid_scores('../trained_models/trained_topographic.pth', n_examples=30)
# Out:
# Trajectory Generator initialized:
# Mean speed: 1.024 m/s
# Mean ego_v (displacement/step): 0.0205 m
# Expected velocity input magnitude: ~0.0205
# ...
# Collected 10/50 batches
# Collected 20/50 batches
# Collected 30/50 batches
# Collected 40/50 batches
# Collected 50/50 batches
# Total samples: 200000
# Computing grid scores for 4096 cells
# Processed 500/4096 cells
# Processed 1000/4096 cells
# Processed 1500/4096 cells
# Processed 2000/4096 cells
# Processed 2500/4096 cells
# Processed 3000/4096 cells
# Processed 3500/4096 cells
# Processed 4000/4096 cells
# Grid scores computed. Range: [-0.371, 1.415]
# Mean: 0.383, Median: 0.335
# Cells with grid score > 0.3: 2200 (53.7%)
