# %%
import os
import sys


directory_path = os.path.abspath('../')

if directory_path not in sys.path:
    sys.path.append(directory_path)

from analyze import visualize_cells

visualize_cells('../trained_models/trained_nontopographic.pth', '../grid_plots', save_imgs=False)
# Out:
# Trajectory Generator initialized:
# Mean speed: 1.024 m/s
# Mean ego_v (displacement/step): 0.0205 m
# Expected velocity input magnitude: ~0.0205
# ...
# Collected 10/50 batches
# Collected 20/50 batches
# Collected 30/50 batches
# Collected 40/50 batches
# Collected 50/50 batches
# Position range: x=[-1.13, 1.13], y=[-1.13, 1.13]
# Making ratemaps for all cells
# Processed 500/4096 cells
# Processed 1000/4096 cells
# Processed 1500/4096 cells
# Processed 2000/4096 cells
# Processed 2500/4096 cells
# Processed 3000/4096 cells
# Processed 3500/4096 cells
# Processed 4000/4096 cells
# Grid scores range: [-0.305, 1.470]
# Mean: 0.337, Median: 0.258
# Saved 100/4096 ratemaps
# Saved 200/4096 ratemaps
# Saved 300/4096 ratemaps
# Saved 400/4096 ratemaps
# Saved 500/4096 ratemaps
# Saved 600/4096 ratemaps
# Saved 700/4096 ratemaps
# Saved 800/4096 ratemaps
# Saved 900/4096 ratemaps
# Saved 1000/4096 ratemaps
# Saved 1100/4096 ratemaps
# Saved 1200/4096 ratemaps
# Saved 1300/4096 ratemaps
# ...

# %%
import os
import sys


directory_path = os.path.abspath('../')

if directory_path not in sys.path:
    sys.path.append(directory_path)

from analyze import visualize_pred
visualize_pred('../trained_models/trained_nontopographic.pth')
# Out:
# Trajectory Generator initialized:
# Mean speed: 1.024 m/s
# Mean ego_v (displacement/step): 0.0205 m
# Expected velocity input magnitude: ~0.0205
# Mean position error: 28.52 cm
# Prediction visualization complete

# %%
import os
import sys


directory_path = os.path.abspath('../')

if directory_path not in sys.path:
    sys.path.append(directory_path)

from analyze import visualize_trajectory_decoding

visualize_trajectory_decoding('../trained_models/trained_nontopographic.pth', n_trajectories=25, seq_length=20)
# Out:
# Trajectory Generator initialized:
# Mean speed: 1.024 m/s
# Mean ego_v (displacement/step): 0.0205 m
# Expected velocity input magnitude: ~0.0205
# Mean position error: 4.51 cm

# %%
import os
import sys


directory_path = os.path.abspath('../')

if directory_path not in sys.path:
    sys.path.append(directory_path)

from analyze import visualize_grid_scores

scores, ratemaps = visualize_grid_scores('../trained_models/trained_nontopographic.pth', n_examples=30)
# Out:
# Trajectory Generator initialized:
# Mean speed: 1.024 m/s
# Mean ego_v (displacement/step): 0.0205 m
# Expected velocity input magnitude: ~0.0205
# ...
# Collected 10/50 batches
# Collected 20/50 batches
# Collected 30/50 batches
# Collected 40/50 batches
# Collected 50/50 batches
# Total samples: 200000
# Computing grid scores for 4096 cells
# Processed 500/4096 cells
# Processed 1000/4096 cells
# Processed 1500/4096 cells
# Processed 2000/4096 cells
# Processed 2500/4096 cells
# Processed 3000/4096 cells
# Processed 3500/4096 cells
# Processed 4000/4096 cells
# Grid scores computed. Range: [-0.305, 1.470]
# Mean: 0.337, Median: 0.258
# Cells with grid score > 0.3: 1865 (45.5%)
